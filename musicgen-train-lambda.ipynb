# %%
# !pip install --upgrade torch-sparse
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install torchaudio
# !pip install --yes protobuf==3.15.0
# !pip install audiocraft
# !pip install lovely_tensors
# !pip install numba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchaudio in /home/ubuntu/.local/lib/python3.8/site-packages (2.0.2)
# Requirement already satisfied: torch==2.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from torchaudio) (2.0.1)
# Requirement already satisfied: networkx in /usr/lib/python3/dist-packages (from torch==2.0.1->torchaudio) (2.4)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.10.3.66)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.7.91)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (10.2.10.91)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (1.12)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (10.9.0.58)
# Requirement already satisfied: triton==2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (2.0.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.7.101)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (2.14.3)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (3.1.2)
# Requirement already satisfied: typing-extensions in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (4.5.0)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.7.4.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch==2.0.1->torchaudio) (11.4.0.1)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch==2.0.1->torchaudio) (3.0.12)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchaudio) (45.2.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchaudio) (0.34.2)
# Requirement already satisfied: cmake in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchaudio) (3.27.0)
# Requirement already satisfied: lit in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchaudio) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from jinja2->torch==2.0.1->torchaudio) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ubuntu/.local/lib/python3.8/site-packages (from sympy->torch==2.0.1->torchaudio) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
#
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --yes
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: audiocraft in /home/ubuntu/.local/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: hydra-core>=1.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (1.3.2)
# Requirement already satisfied: sentencepiece in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.1.99)
# Requirement already satisfied: flashy>=0.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.0.2)
# Requirement already satisfied: torch>=2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (2.0.1)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (4.64.1)
# Requirement already satisfied: librosa in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.10.0.post2)
# Requirement already satisfied: torchaudio>=2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (2.0.2)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (1.23.5)
# Requirement already satisfied: xformers in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.0.20)
# Requirement already satisfied: demucs in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (4.0.0)
# Requirement already satisfied: hydra-colorlog in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (1.2.0)
# Requirement already satisfied: av in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (10.0.0)
# Requirement already satisfied: einops in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.6.1)
# Requirement already satisfied: num2words in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.5.12)
# Requirement already satisfied: transformers in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (4.31.0)
# Requirement already satisfied: spacy==3.5.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (3.5.2)
# Requirement already satisfied: julius in /home/ubuntu/.local/lib/python3.8/site-packages (from audiocraft) (0.2.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (3.0.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (1.10.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (8.1.10)
# Requirement already satisfied: pathy>=0.10.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (0.10.2)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (2.0.7)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy==3.5.2->audiocraft) (45.2.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (2.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (6.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (2.4.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (2.28.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from spacy==3.5.2->audiocraft) (1.1.2)
# Requirement already satisfied: dora-search in /home/ubuntu/.local/lib/python3.8/site-packages (from flashy>=0.0.1->audiocraft) (0.1.12)
# Requirement already satisfied: colorlog in /home/ubuntu/.local/lib/python3.8/site-packages (from flashy>=0.0.1->audiocraft) (6.7.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ubuntu/.local/lib/python3.8/site-packages (from hydra-core>=1.1->audiocraft) (4.9.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from hydra-core>=1.1->audiocraft) (2.3.0)
# Requirement already satisfied: importlib-resources in /home/ubuntu/.local/lib/python3.8/site-packages (from hydra-core>=1.1->audiocraft) (5.12.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (8.5.0.96)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.7.101)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.4.0.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.7.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.7.99)
# Requirement already satisfied: triton==2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (2.0.0)
# Requirement already satisfied: networkx in /usr/lib/python3/dist-packages (from torch>=2.0.0->audiocraft) (2.4)
# Requirement already satisfied: typing-extensions in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (4.5.0)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (11.7.4.91)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch>=2.0.0->audiocraft) (3.0.12)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (10.9.0.58)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.8/site-packages (from torch>=2.0.0->audiocraft) (1.12)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=2.0.0->audiocraft) (0.34.2)
# Requirement already satisfied: lit in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch>=2.0.0->audiocraft) (16.0.6)
# Requirement already satisfied: cmake in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch>=2.0.0->audiocraft) (3.27.0)
# Requirement already satisfied: diffq>=0.2.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from demucs->audiocraft) (0.2.4)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from demucs->audiocraft) (5.3.1)
# Requirement already satisfied: lameenc>=1.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from demucs->audiocraft) (1.5.1)
# Requirement already satisfied: openunmix in /home/ubuntu/.local/lib/python3.8/site-packages (from demucs->audiocraft) (1.2.1)
# Requirement already satisfied: lazy-loader>=0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (0.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/lib/python3/dist-packages (from librosa->audiocraft) (0.22.2.post1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (1.6.0)
# Requirement already satisfied: soundfile>=0.12.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (0.12.1)
# Requirement already satisfied: msgpack>=1.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (1.0.5)
# Requirement already satisfied: joblib>=0.14 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (1.2.0)
# Requirement already satisfied: numba>=0.51.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (0.57.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (1.9.3)
# Requirement already satisfied: soxr>=0.3.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (0.3.5)
# Requirement already satisfied: decorator>=4.3.0 in /usr/lib/python3/dist-packages (from librosa->audiocraft) (4.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/ubuntu/.local/lib/python3.8/site-packages (from librosa->audiocraft) (3.0.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from num2words->audiocraft) (0.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from transformers->audiocraft) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from transformers->audiocraft) (0.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from transformers->audiocraft) (0.16.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.8/site-packages (from transformers->audiocraft) (2023.6.3)
# Requirement already satisfied: pyre-extensions==0.0.29 in /home/ubuntu/.local/lib/python3.8/site-packages (from xformers->audiocraft) (0.0.29)
# Requirement already satisfied: typing-inspect in /home/ubuntu/.local/lib/python3.8/site-packages (from pyre-extensions==0.0.29->xformers->audiocraft) (0.9.0)
# Requirement already satisfied: Cython in /usr/lib/python3/dist-packages (from diffq>=0.2.1->demucs->audiocraft) (0.29.14)
# Requirement already satisfied: fsspec in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->audiocraft) (0.6.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/ubuntu/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa->audiocraft) (0.40.1)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa->audiocraft) (6.0.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/lib/python3/dist-packages (from pooch<1.7,>=1.0->librosa->audiocraft) (1.4.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (2019.11.28)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (1.26.16)
# Requirement already satisfied: cffi>=1.0 in /usr/lib/python3/dist-packages (from soundfile>=0.12.1->librosa->audiocraft) (1.14.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ubuntu/.local/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->audiocraft) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->audiocraft) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.2->audiocraft) (8.1.6)
# Requirement already satisfied: submitit in /home/ubuntu/.local/lib/python3.8/site-packages (from dora-search->flashy>=0.0.1->audiocraft) (1.4.5)
# Requirement already satisfied: retrying in /home/ubuntu/.local/lib/python3.8/site-packages (from dora-search->flashy>=0.0.1->audiocraft) (1.3.4)
# Requirement already satisfied: treetable in /home/ubuntu/.local/lib/python3.8/site-packages (from dora-search->flashy>=0.0.1->audiocraft) (0.2.5)
# Requirement already satisfied: zipp>=3.1.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from importlib-resources->hydra-core>=1.1->audiocraft) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from jinja2->spacy==3.5.2->audiocraft) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ubuntu/.local/lib/python3.8/site-packages (from sympy->torch>=2.0.0->audiocraft) (1.3.0)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->dora-search->flashy>=0.0.1->audiocraft) (1.14.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/lib/python3/dist-packages (from submitit->dora-search->flashy>=0.0.1->audiocraft) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from typing-inspect->pyre-extensions==0.0.29->xformers->audiocraft) (1.0.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lovely_tensors in /home/ubuntu/.local/lib/python3.8/site-packages (0.1.15)
# Requirement already satisfied: torch in /home/ubuntu/.local/lib/python3.8/site-packages (from lovely_tensors) (2.0.1)
# Requirement already satisfied: lovely-numpy>=0.2.9 in /home/ubuntu/.local/lib/python3.8/site-packages (from lovely_tensors) (0.2.9)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from lovely-numpy>=0.2.9->lovely_tensors) (7.0.0)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.8/site-packages (from lovely-numpy>=0.2.9->lovely_tensors) (1.23.5)
# Requirement already satisfied: ipython in /usr/lib/python3/dist-packages (from lovely-numpy>=0.2.9->lovely_tensors) (7.13.0)
# Requirement already satisfied: fastcore in /home/ubuntu/.local/lib/python3.8/site-packages (from lovely-numpy>=0.2.9->lovely_tensors) (1.5.29)
# Requirement already satisfied: matplotlib in /home/ubuntu/.local/lib/python3.8/site-packages (from lovely-numpy>=0.2.9->lovely_tensors) (3.6.3)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch->lovely_tensors) (3.0.12)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (2.14.3)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (3.1.2)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (8.5.0.96)
# Requirement already satisfied: networkx in /usr/lib/python3/dist-packages (from torch->lovely_tensors) (2.4)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (2.0.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.7.101)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (10.9.0.58)
# Requirement already satisfied: typing-extensions in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.7.99)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.4.0.1)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (10.2.10.91)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/ubuntu/.local/lib/python3.8/site-packages (from torch->lovely_tensors) (11.7.4.91)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->lovely_tensors) (45.2.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->lovely_tensors) (0.34.2)
# Requirement already satisfied: lit in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch->lovely_tensors) (16.0.6)
# Requirement already satisfied: cmake in /home/ubuntu/.local/lib/python3.8/site-packages (from triton==2.0.0->torch->lovely_tensors) (3.27.0)
# Requirement already satisfied: pip in /home/ubuntu/.local/lib/python3.8/site-packages (from fastcore->lovely-numpy>=0.2.9->lovely_tensors) (23.0.1)
# Requirement already satisfied: packaging in /home/ubuntu/.local/lib/python3.8/site-packages (from fastcore->lovely-numpy>=0.2.9->lovely_tensors) (23.0)
# Requirement already satisfied: pexpect in /usr/lib/python3/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely_tensors) (4.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from jinja2->torch->lovely_tensors) (2.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (2.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (4.39.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/.local/lib/python3.8/site-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (0.10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ubuntu/.local/lib/python3.8/site-packages (from sympy->torch->lovely_tensors) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->lovely-numpy>=0.2.9->lovely_tensors) (1.14.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numba in /home/ubuntu/.local/lib/python3.8/site-packages (0.57.1)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/.local/lib/python3.8/site-packages (from numba) (6.0.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/ubuntu/.local/lib/python3.8/site-packages (from numba) (0.40.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in /home/ubuntu/.local/lib/python3.8/site-packages (from numba) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/.local/lib/python3.8/site-packages (from importlib-metadata->numba) (3.15.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import torchaudio
from audiocraft.models import MusicGen
from transformers import get_scheduler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import AdamW
import random

from torch.utils.data import Dataset

from audiocraft.modules.conditioners import ClassifierFreeGuidanceDropout

import os
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# !pip install  wandb==0.12.17
# import wandb
# wandb.login()

# %%
# from https://github.com/neverix/musicgen_trainer/blob/main/train.py

class AudioDataset(Dataset):
    def __init__(self, data_dir, no_label=False):
        self.data_dir = data_dir
        self.data_map = []

        dir_map = os.listdir(data_dir)
        for d in dir_map:
            name, ext = os.path.splitext(d)
            if ext == ".wav":
                if no_label:
                    self.data_map.append({"audio": os.path.join(data_dir, d)})
                    continue
                if os.path.exists(os.path.join(data_dir, name + ".txt")):
                    self.data_map.append(
                        {
                            "audio": os.path.join(data_dir, d),
                            "label": os.path.join(data_dir, name + ".txt"),
                        }
                    )
                else:
                    raise ValueError(f"No label file for {name}")

    def __len__(self):
        return len(self.data_map)

    def __getitem__(self, idx):
        data = self.data_map[idx]
        audio = data["audio"]
        label = data.get("label", "")

        return audio, label


def count_nans(tensor):
    nan_mask = torch.isnan(tensor)
    num_nans = torch.sum(nan_mask).item()
    return num_nans


def preprocess_audio(audio_path, model: MusicGen, duration: int = 30):
    wav, sr = torchaudio.load(audio_path)
    wav = torchaudio.functional.resample(wav, sr, model.sample_rate)
    wav = wav.mean(dim=0, keepdim=True)
    if wav.shape[1] < model.sample_rate * duration:
        return None
    end_sample = int(model.sample_rate * duration)
    start_sample = random.randrange(0, max(wav.shape[1] - end_sample, 1))
    wav = wav[:, start_sample : start_sample + end_sample]

    assert wav.shape[0] == 1

    wav = wav.cuda()
    wav = wav.unsqueeze(1)

    with torch.no_grad():
        gen_audio = model.compression_model.encode(wav)

    codes, scale = gen_audio

    assert scale is None

    return codes


def fixnan(tensor: torch.Tensor):
    nan_mask = torch.isnan(tensor)
    result = torch.where(nan_mask, torch.zeros_like(tensor), tensor)

    return result


def one_hot_encode(tensor, num_classes=2048):
    shape = tensor.shape
    one_hot = torch.zeros((shape[0], shape[1], num_classes))

    for i in range(shape[0]):
        for j in range(shape[1]):
            index = tensor[i, j].item()
            one_hot[i, j, index] = 1

    return one_hot


def train(
    dataset_path: str,
    model_id: str,
    lr: float,
    epochs: int,
    use_wandb: bool,
    no_label: bool = False,
    tune_text: bool = False,
    save_step: int = None,
    grad_acc: int = 8,
    use_scaler: bool = False,
    weight_decay: float = 1e-5,
    warmup_steps: int = 10,
    batch_size: int = 10,
    use_cfg: bool = False
):
    if use_wandb:
        run = wandb.init(project="audiocraft")

    model = MusicGen.get_pretrained(model_id)
    model.lm = model.lm.to(torch.float32)  # important

    dataset = AudioDataset(dataset_path, no_label=no_label)
    train_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    learning_rate = lr
    model.lm.train()

    scaler = torch.cuda.amp.GradScaler()

    if tune_text:
        print("Tuning text")
    else:
        print("Tuning everything")

    # from paper
    optimizer = AdamW(
        model.lm.condition_provider.parameters()
        if tune_text
        else model.lm.parameters(),
        lr=learning_rate,
        betas=(0.9, 0.95),
        weight_decay=weight_decay,
    )
    scheduler = get_scheduler(
        "cosine",
        optimizer,
        warmup_steps,
        int(epochs * len(train_dataloader) / grad_acc),
    )

    criterion = nn.CrossEntropyLoss()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    num_epochs = epochs

    save_step = save_step
    save_models = False if save_step is None else True

    save_path = "models/"

    save_path = os.path.join(dataset_path,save_path)

    os.makedirs(save_path, exist_ok=True)

    current_step = 0

    for epoch in range(num_epochs):
        for batch_idx, (audio, label) in enumerate(train_dataloader):

            # Visualize GPU usage
            # print(torch.cuda.memory_summary(device=None, abbreviated=False))

            optimizer.zero_grad()

            all_codes = []
            texts = []

            # where audio and label are just paths
            for inner_audio, l in zip(audio, label):
                inner_audio = preprocess_audio(inner_audio, model)  # returns tensor
                if inner_audio is None:
                    continue

                if use_cfg:
                    codes = torch.cat([inner_audio, inner_audio], dim=0)
                else:
                    codes = inner_audio

                all_codes.append(codes)
                texts.append(open(l, "r").read().strip())

            attributes, _ = model._prepare_tokens_and_attributes(texts, None)
            conditions = attributes
            if use_cfg:
                null_conditions = ClassifierFreeGuidanceDropout(p=1.0)(conditions)
                conditions = conditions + null_conditions
            tokenized = model.lm.condition_provider.tokenize(conditions)
            cfg_conditions = model.lm.condition_provider(tokenized)
            condition_tensors = cfg_conditions

            if len(all_codes) == 0:
                continue

            codes = torch.cat(all_codes, dim=0)

            with torch.autocast(device_type="cuda", dtype=torch.float16):
                lm_output = model.lm.compute_predictions(
                    codes=codes, conditions=[], condition_tensors=condition_tensors
                )

                codes = codes[0]
                logits = lm_output.logits[0]
                mask = lm_output.mask[0]

                codes = one_hot_encode(codes, num_classes=2048)

                # only if cuda has enough memory should we load the variables into the GPU RAM
                if torch.cuda.is_available():
                    codes = codes.cuda()
                    logits = logits.cuda()
                    mask = mask.cuda()

                mask = mask.view(-1)
                masked_logits = logits.view(-1, 2048)[mask]
                masked_codes = codes.view(-1, 2048)[mask]

                loss = criterion(masked_logits, masked_codes)

            current_step += 1 / grad_acc

            # assert count_nans(masked_logits) == 0

            (scaler.scale(loss) if use_scaler else loss).backward()

            total_norm = 0
            for p in model.lm.condition_provider.parameters():
                try:
                    param_norm = p.grad.data.norm(2)
                    total_norm += param_norm.item() ** 2
                except AttributeError:
                    pass
            total_norm = total_norm ** (1.0 / 2)

            if use_wandb:
                run.log(
                    {
                        "loss": loss.item(),
                        "total_norm": total_norm,
                    }
                )

            print(
                f"Epoch: {epoch}/{num_epochs}, Batch: {batch_idx}/{len(train_dataloader)}, Loss: {loss.item()}"
            )

            if batch_idx % grad_acc != grad_acc - 1:
                continue

            if use_scaler:
                scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.lm.parameters(), 0.5)

            if use_scaler:
                scaler.step(optimizer)
                scaler.update()
            else:
                optimizer.step()
            scheduler.step()

            if save_models:
                if (
                    current_step == int(current_step)
                    and int(current_step) % save_step == 0
                ):
                    torch.save(
                        model.lm.state_dict(), f"{save_path}/lm_{current_step}.pt"
                    )

    torch.save(model.lm.state_dict(), f"{save_path}/lm_final.pt")

# %% [markdown]
# path = '/home/ubuntu/train'
#
# import torch
# torch.cuda.empty_cache()
#
# train(
#     dataset_path = path,
#     model_id = 'small',
#     lr = 1e-5,
#     epochs = 5,
#     use_wandb = False,
#     no_label = False,
#     tune_text = False,
#     save_step = None,
#     grad_acc = 8,
#     use_scaler = False,
#     weight_decay = 1e-5,
#     warmup_steps = 10,
#     batch_size = 5,
#     use_cfg = False
# )
